# %%
from openai import OpenAI

# Define your endpoint and API key here
endpoint = "your_endpoint_here"  # Replace with your actual endpoint
api_key = "your_api_key_here"  # Replace with your actual API key

client = OpenAI(
    base_url=f"{endpoint}",
    api_key=api_key
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_482/3663917616.py in <cell line: 0>()
#       2
#       3 client = OpenAI(
# ----> 4     base_url=f"{endpoint}",
#       5     api_key=api_key
#       6 )
#
# NameError: name 'endpoint' is not defined

# %%
pip install openai

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
from openai import OpenAI

client = OpenAI(
    base_url=f"{endpoint}",
    api_key=api_key
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_482/3663917616.py in <cell line: 0>()
#       2
#       3 client = OpenAI(
# ----> 4     base_url=f"{endpoint}",
#       5     api_key=api_key
#       6 )
#
# NameError: name 'endpoint' is not defined

# %%
# !pip install -q openai

# %%
from openai import OpenAI

api_key = "YOUR_OPENAI_API_KEY"

client = OpenAI(api_key=api_key)

# %%
from openai import OpenAI

api_key = "YOUR_AZURE_API_KEY"

client = OpenAI(api_key=api_key)

# %%
from openai import OpenAI

endpoint = "https://YOUR_RESOURCE_NAME.openai.azure.com/openai/v1/"
api_key = "YOUR_AZURE_API_KEY"

client = OpenAI(
    base_url=endpoint,
    api_key=api_key
)

# %%
from openai import OpenAI

endpoint = "https://ctp01.services.ai.azure.com/openai/v1/"
model_name = "Phi-4-mini-reasoning"
deployment_name = "Phi-4-mini-reasoning"

api_key = "YOUR_AZURE_API_KEY"

client = OpenAI(
    base_url=f"{endpoint}",
    api_key=api_key
)

completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "user",
            "content": "What is the capital of India?",
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='<think>\n\nOkay, so I need to figure out the capital of India. Let me start by recalling what I know about countries and their capitals. I remember that each country has a capital city, which is its official administrative capital. Sometimes there are other cities that are more cultural or economic centers, but the capital is the official one.\n\nIndia is a large country in South Asia. I know that its main cities include Mumbai, Delhi, Bangalore, Hyderabad, and Kolkata. But which one is the capital? I think Delhi is the capital, but I\'m not 100% sure. Wait, I\'ve heard people refer to New Delhi as the capital. Are they the same thing? Maybe Delhi refers to the older city, and New Delhi is the expanded capital area? Or are they separate?\n\nLet me think. When I traveled before, seeing photos of India, Delhi often comes up as the capital. But sometimes New Delhi is mentioned in news articles about political events because that\'s where the government bui
# ...

# %%
from openai import OpenAI

endpoint = "https://ctp01.services.ai.azure.com/openai/v1/"
model_name = "Phi-4-mini-reasoning"
deployment_name = "Phi-4-mini-reasoning"

api_key = "YOUR_AZURE_API_KEY"
client = OpenAI(
    base_url=f"{endpoint}",
    api_key=api_key
)

completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "user",
            "content": "What is the capital of Australia?",
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='<think>\n\nOkay, so I need to figure out the capital of Australia. Let me start by recalling what I know about countries and their capitals. I remember that many countries have a capital city which is their official principal city. For example, Paris is the capital of France, Canberra is the capital of Australia—wait, is that right? Or was it Melbourne? Hmm, I might be mixing some of them up.\n\nWait, I think Australia has a unique situation because they moved their capital from Canberra to Sydney. No, wait, that doesn\'t sound right. Let me think again. I recall that Canberra was planned as the capital when Australia became a federation in the 19th century. But then there\'s been talk or maybe actual moves to Sydney because it\'s a larger city and a major financial center. Or is the capital still Canberra despite that?\n\nAlternatively, maybe I\'m confusing it with other countries. For instance, I\'d think Bogota is the capital of Colombia, but maybe s
# ...
